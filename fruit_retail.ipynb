# %% [markdown]
# #  Fruits: Retail Prices of Agricultural Commodities by Geolocation, Commodity, Year and Period
# Problems:
# 1. What fruit prices are expected to increase and decrease?
# 2. What place/s sell fruits at higher prices
# 3. Does seasons affect fruit prices
#
# Goal:
# 1. Find the specialty of each province.
# 2. Forecast fruit prices.
# 3. Find out the effect of seasons on fruit prices.
#
# dataset from:\
# https://openstat.psa.gov.ph/PXWeb/pxweb/en/DB/DB__2M__2018/0042M4ARA07.px/?rxid=7d5d3588-67ae-4206-8670-09322cda2f17

# %% [markdown]
# # Methodology
# 1. Reading and Understanding the Data\
# a. Creating a Data Dictionary
# 2. Data Cleaning
# 3. Data Preparation
# 4. Statistical Data Analysis\
# a. Univariate Analysis\
# b. Bivariate Analysis
# 5. Final Analysis

# %% [markdown]
# ### 1. Reading and Understanding the Data

# %%
# import libraries for dataframe and visualizations
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import plotly as py
import plotly.graph_objs as go

from plotly.offline import init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

# import required libraries for clustering
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import cut_tree

# import required libraries for time series analysis
from statsmodels.tsa.statespace.sarimax import SARIMAX

# remove unnecesary warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# 1. Reading the data on which analysis needs to be done

df = pd.read_excel("Retail prices of fruits by region 2018-2024.xlsx", header=3)
df = df[:-31]

df.tail(5)
# Out:
#     Unnamed: 0                                       Unnamed: 1 January  \
# 643        NaN  FRESH FRUIT, MANDARIN, DALANGHITA, MEDIUM, 1 KG      ..
# 644        NaN                           CALAMANSI, LOOSE, 1 KG   119.9
# 645        NaN  FRESH FRUIT, APPLE, RED DELICIOUS, MEDIUM, 1 KG      ..
# 646        NaN     FRESH FRUIT, CANTALOUPE, MELON, MEDIUM, 1 KG      ..
# 647        NaN    FRESH FRUIT, WATERMELON, PAKWAN, MEDIUM, 1 KG   18.51
#
#     February   March   April     May   June    July  August  ... April.6  \
# 643       ..      ..      ..      ..     ..      ..      ..  ...      ..
# 644    119.9  130.43  119.89  119.89  121.5  120.22  120.97  ...   56.17
# 645       ..      ..      ..      ..     ..      ..      ..  ...      ..
# 646       ..      ..      ..      ..     ..      ..      ..  ...      ..
# 647    18.51   17.77   19.75   19.75  19.75   19.75   19.75  ...   34.58
#
#      May.6 June.6 July.6 August.6 September.6 October.6 November.6 December.6  \
# 643     ..     ..     ..       ..          ..        ..         ..         ..
# 644  56.67  58.46  56.78    56.71       57.57        ..         ..         ..
# 645     ..     ..     ..       ..          ..        ..         ..         ..
# 646     ..     ..     ..       ..          ..        ..         ..         ..
# 647  33.33     31  31.67    31.33        33.5        ..         ..         ..
#
#     Annual.6
# 643       ..
# 644       ..
# 645       ..
# 646       ..
# 647       ..
#
# [5 rows x 93 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 648 entries, 0 to 647
# Data columns (total 93 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   18 non-null     object
#  1   Unnamed: 1   648 non-null    object
#  2   January      648 non-null    object
#  3   February     648 non-null    object
#  4   March        648 non-null    object
#  5   April        648 non-null    object
#  6   May          648 non-null    object
#  7   June         648 non-null    object
#  8   July         648 non-null    object
#  9   August       648 non-null    object
#  10  September    648 non-null    object
#  11  October      648 non-null    object
#  12  November     648 non-null    object
#  13  December     648 non-null    object
#  14  Annual       648 non-null    object
#  15  January.1    648 non-null    object
#  16  February.1   648 non-null    object
#  17  March.1      648 non-null    object
#  18  April.1      648 non-null    object
#  19  May.1        648 non-null    object
#  20  June.1       648 non-null    object
#  21  July.1       648 non-null    object
#  22  August.1     648 non-null    object
#  23  September.1  648 non-null    object
#  24  October.1    648 non-null    object
#  25  November.1   648 non-null    object
#  26  December.1   648 non-null    object
#  27  Annual.1     648 non-null    object
#  28  January.2    648 non-null    object
#  29  February.2   648 non-null    object
#  30  March.2      648 non-null    object
#  31  April.2      648 non-null    object
#  32  May.2        648 non-null    object
#  33  June.2       648 non-null    object
#  34  July.2       648 non-null    object
#  35  August.2     648 non-null    object
#  36  September.2  648 non-null    object
#  37  October.2    648 non-null    object
#  38  November.2   648 non-null    object
#  39  December.2   648 non-null    object
#  40  Annual.2     648 non-null    object
#  41  January.3    648 non-null    object
#  42  February.3   648 non-null    object
#  43  March.3      648 non-null    object
#  44  April.3      648 non-null    object
#  45  May.3        648 non-null    object
#  46  June.3       648 non-null    object
#  47  July.3       648 non-null    object
#  48  August.3     648 non-null    object
#  49  September.3  648 non-null    object
#  50  October.3    648 non-null    object
#  51  November.3   648 non-null    object
#  52  December.3   648 non-null    object
#  53  Annual.3     648 non-null    object
#  54  January.4    648 non-null    object
#  55  February.4   648 non-null    object
#  56  March.4      648 non-null    object
#  57  April.4      648 non-null    object
#  58  May.4        648 non-null    object
#  59  June.4       648 non-null    object
#  60  July.4       648 non-null    object
#  61  August.4     648 non-null    object
#  62  September.4  648 non-null    object
#  63  October.4    648 non-null    object
#  64  November.4   648 non-null    object
#  65  December.4   648 non-null    object
#  66  Annual.4     648 non-null    object
#  67  January.5    648 non-null    object
#  68  February.5   648 non-null    object
#  69  March.5      648 non-null    object
#  70  April.5      648 non-null    object
#  71  May.5        648 non-null    object
#  72  June.5       648 non-null    object
#  73  July.5       648 non-null    object
#  74  August.5     648 non-null    object
#  75  September.5  648 non-null    object
#  76  October.5    648 non-null    object
#  77  November.5   648 non-null    object
#  78  December.5   648 non-null    object
#  79  Annual.5     648 non-null    object
#  80  January.6    648 non-null    object
#  81  February.6   648 non-null    object
#  82  March.6      648 non-null    object
#  83  April.6      648 non-null    object
#  84  May.6        648 non-null    object
#  85  June.6       648 non-null    object
#  86  July.6       648 non-null    object
#  87  August.6     648 non-null    object
#  88  September.6  648 non-null    object
#  89  October.6    648 non-null    object
#  90  November.6   648 non-null    object
#  91  December.6   648 non-null    object
#  92  Annual.6     648 non-null    object
# dtypes: object(93)
# memory usage: 470.9+ KB

# %%
df.describe()
# Out:
#          Unnamed: 0                  Unnamed: 1 January February March April  \
# count            18                         648     648      648   648   648
# unique           18                          36     288      286   288   289
# top     PHILIPPINES  FRESH FRUIT, AVOCADO, 1 KG      ..       ..    ..    ..
# freq              1                          18     358      358   358   358
#
#         May June July August  ... April.6 May.6 June.6 July.6 August.6  \
# count   648  648  648    648  ...     648   648    648    648      648
# unique  287  287  288    287  ...     283   281    278    270      280
# top      ..   ..   ..     ..  ...      ..    ..     ..     ..       ..
# freq    358  358  358    358  ...     358   358    358    358      358
#
#        September.6 October.6 November.6 December.6 Annual.6
# count          648       648        648        648      648
# unique         278         1          1          1        1
# top             ..        ..         ..         ..       ..
# freq           358       648        648        648      648
#
# [4 rows x 93 columns]

# %%
df.replace("..", np.nan, inplace=True)

# %%
# check for nulls
sns.heatmap(df.isnull(), cbar=False, yticklabels=False)
# Out:
# <Axes: >

# %%
df.tail(5)
# Out:
#     Unnamed: 0                                       Unnamed: 1  January  \
# 643        NaN  FRESH FRUIT, MANDARIN, DALANGHITA, MEDIUM, 1 KG      NaN
# 644        NaN                           CALAMANSI, LOOSE, 1 KG   119.90
# 645        NaN  FRESH FRUIT, APPLE, RED DELICIOUS, MEDIUM, 1 KG      NaN
# 646        NaN     FRESH FRUIT, CANTALOUPE, MELON, MEDIUM, 1 KG      NaN
# 647        NaN    FRESH FRUIT, WATERMELON, PAKWAN, MEDIUM, 1 KG    18.51
#
#      February   March   April     May    June    July  August  ...  April.6  \
# 643       NaN     NaN     NaN     NaN     NaN     NaN     NaN  ...      NaN
# 644    119.90  130.43  119.89  119.89  121.50  120.22  120.97  ...    56.17
# 645       NaN     NaN     NaN     NaN     NaN     NaN     NaN  ...      NaN
# 646       NaN     NaN     NaN     NaN     NaN     NaN     NaN  ...      NaN
# 647     18.51   17.77   19.75   19.75   19.75   19.75   19.75  ...    34.58
#
#      May.6  June.6  July.6  August.6  September.6  October.6  November.6  \
# 643    NaN     NaN     NaN       NaN          NaN        NaN         NaN
# 644  56.67   58.46   56.78     56.71        57.57        NaN         NaN
# 645    NaN     NaN     NaN       NaN          NaN        NaN         NaN
# 646    NaN     NaN     NaN       NaN          NaN        NaN         NaN
# 647  33.33   31.00   31.67     31.33        33.50        NaN         NaN
#
#      December.6  Annual.6
# 643         NaN       NaN
# 644         NaN       NaN
# 645         NaN       NaN
# 646         NaN       NaN
# 647         NaN       NaN
#
# [5 rows x 93 columns]

# %%
# Calculating the Missing Values % contribution in DF
df_null = round(100*(df.isnull().sum())/len(df), 2)
# Convert the Series to a DataFrame and display it
df_null = df_null.reset_index()
df_null.columns = ['Column', 'Percentage']
df_null
# Out:
#          Column  Percentage
# 0    Unnamed: 0       97.22
# 1    Unnamed: 1        0.00
# 2       January       55.25
# 3      February       55.25
# 4         March       55.25
# ..          ...         ...
# 88  September.6       55.25
# 89    October.6      100.00
# 90   November.6      100.00
# 91   December.6      100.00
# 92     Annual.6      100.00
#
# [93 rows x 2 columns]

# %% [markdown]
# ### 2. Data Cleaning

# %%
# Forward-fill the regions (Unnamed: 0) and product names (Unnamed: 1) to deal with the multi-level structure
df['Unnamed: 0'].ffill(inplace=True)  # Regions
df['Unnamed: 1'].ffill(inplace=True)  # Products


df.rename(columns={'Unnamed: 0': 'Region', 'Unnamed: 1': 'Product'}, inplace=True)

df_cleaned = df.loc[:, ~df.columns.str.contains('Annual')]

years = []
current_year = 2018  

for col in df_cleaned.columns[2:]:  
    if 'January' in col:
        years.append(str(current_year))
        current_year += 1
    else:
        years.append(str(current_year - 1))  

# Assign the months in a repeating sequence (January to December)
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
months_repeated = months * (len(df_cleaned.columns[2:]) // 12)

# Create a MultiIndex for the columns with Year and Month
df_cleaned.columns = pd.MultiIndex.from_tuples([('Region', ''), ('Product', '')] + list(zip(years, months_repeated)))

# Melt the data with Region and Product as identifiers
df_melted = pd.melt(
    df_cleaned, 
    id_vars=['Region', 'Product'], 
    var_name=['Year', 'Month'], 
    value_name='Price'
)

# Replace '..' with NaN and drop rows where Price is NaN
df_melted.replace('..', pd.NA, inplace=True)
df_melted.dropna(subset=['Price'], inplace=True)

df_melted.tail()
# Out:
#                                               Region  \
# 52473  ..AUTONOMOUS REGION IN MUSLIM MINDANAO (ARMM)
# 52478  ..AUTONOMOUS REGION IN MUSLIM MINDANAO (ARMM)
# 52479  ..AUTONOMOUS REGION IN MUSLIM MINDANAO (ARMM)
# 52484  ..AUTONOMOUS REGION IN MUSLIM MINDANAO (ARMM)
# 52487  ..AUTONOMOUS REGION IN MUSLIM MINDANAO (ARMM)
#
#                                              Product  Year      Month   Price
# 52473                      FRESH FRUIT, GRAPES, 1 KG  2024  September  305.00
# 52478                    FRESH FRUIT, LANZONES, 1 KG  2024  September   59.00
# 52479                    FRESH FRUIT, RAMBUTAN, 1 KG  2024  September   60.00
# 52484                         CALAMANSI, LOOSE, 1 KG  2024  September   57.57
# 52487  FRESH FRUIT, WATERMELON, PAKWAN, MEDIUM, 1 KG  2024  September   33.50

# %%
df_melted['Region'] = df_melted['Region'].str.replace('.', '', regex=False)
df_melted.tail(5)
# Out:
#                                             Region  \
# 52473  AUTONOMOUS REGION IN MUSLIM MINDANAO (ARMM)
# 52478  AUTONOMOUS REGION IN MUSLIM MINDANAO (ARMM)
# 52479  AUTONOMOUS REGION IN MUSLIM MINDANAO (ARMM)
# 52484  AUTONOMOUS REGION IN MUSLIM MINDANAO (ARMM)
# 52487  AUTONOMOUS REGION IN MUSLIM MINDANAO (ARMM)
#
#                                              Product  Year      Month   Price
# 52473                      FRESH FRUIT, GRAPES, 1 KG  2024  September  305.00
# 52478                    FRESH FRUIT, LANZONES, 1 KG  2024  September   59.00
# 52479                    FRESH FRUIT, RAMBUTAN, 1 KG  2024  September   60.00
# 52484                         CALAMANSI, LOOSE, 1 KG  2024  September   57.57
# 52487  FRESH FRUIT, WATERMELON, PAKWAN, MEDIUM, 1 KG  2024  September   33.50

# %%
df_melted.to_csv('prutas_long.csv')

# %%
# Extract the abbreviation enclosed in parentheses from the Region column
df_melted['Region Abbreviation'] = df_melted['Region'].str.extract(r'\((.*?)\)')

# Remove the copied part in Region
df_melted['Region'] = df_melted['Region'].str.replace(r'\(.*?\)', '', regex=True).str.strip()

df_melted.tail()
# Out:
#                                      Region  \
# 52473  AUTONOMOUS REGION IN MUSLIM MINDANAO
# 52478  AUTONOMOUS REGION IN MUSLIM MINDANAO
# 52479  AUTONOMOUS REGION IN MUSLIM MINDANAO
# 52484  AUTONOMOUS REGION IN MUSLIM MINDANAO
# 52487  AUTONOMOUS REGION IN MUSLIM MINDANAO
#
#                                              Product  Year      Month   Price  \
# 52473                      FRESH FRUIT, GRAPES, 1 KG  2024  September  305.00
# 52478                    FRESH FRUIT, LANZONES, 1 KG  2024  September   59.00
# 52479                    FRESH FRUIT, RAMBUTAN, 1 KG  2024  September   60.00
# 52484                         CALAMANSI, LOOSE, 1 KG  2024  September   57.57
# 52487  FRESH FRUIT, WATERMELON, PAKWAN, MEDIUM, 1 KG  2024  September   33.50
#
#       Region Abbreviation
# 52473                ARMM
# 52478                ARMM
# 52479                ARMM
# 52484                ARMM
# 52487                ARMM

# %%
# Update the Region Abbreviation column for rows where Region is 'MIMAROPA REGION'
df_melted.loc[df_melted['Region'] == 'MIMAROPA REGION', 'Region Abbreviation'] = 'MIMAROPA'
df_melted.loc[df_melted['Region'] == 'PHILIPPINES', 'Region Abbreviation'] = 'PH'

# verify changes
df_melted[df_melted['Region'] == 'MIMAROPA REGION'].head()
# Out:
#               Region                                          Product  Year  \
# 254  MIMAROPA REGION       FRESH FRUIT, BANANA, LAKATAN, MEDIUM, 1 KG  2018
# 255  MIMAROPA REGION      FRESH FRUIT, BANANA, LATUNDAN, MEDIUM, 1 KG  2018
# 256  MIMAROPA REGION          FRESH FRUIT, BANANA, SABA, MEDIUM, 1 KG  2018
# 260  MIMAROPA REGION  FRESH FRUIT, MANGO, KALABAW, RIPE, MEDIUM, 1 KG  2018
# 263  MIMAROPA REGION     FRESH FRUIT, MANGO, PIKO, RIPE, MEDIUM, 1 KG  2018
#
#        Month   Price Region Abbreviation
# 254  January   65.82            MIMAROPA
# 255  January   52.70            MIMAROPA
# 256  January   32.75            MIMAROPA
# 260  January  101.04            MIMAROPA
# 263  January  116.44            MIMAROPA

# %%
df_melted[df_melted['Region'] == 'PHILIPPINES'].head()
# Out:
#         Region                                      Product  Year    Month  \
# 0  PHILIPPINES                   FRESH FRUIT, AVOCADO, 1 KG  2018  January
# 1  PHILIPPINES   FRESH FRUIT, BANANA, CARDAVA, MEDIUM, 1 KG  2018  January
# 2  PHILIPPINES   FRESH FRUIT, BANANA, LAKATAN, MEDIUM, 1 KG  2018  January
# 3  PHILIPPINES  FRESH FRUIT, BANANA, LATUNDAN, MEDIUM, 1 KG  2018  January
# 4  PHILIPPINES      FRESH FRUIT, BANANA, SABA, MEDIUM, 1 KG  2018  January
#
#    Price Region Abbreviation
# 0  63.90                  PH
# 1  26.68                  PH
# 2  52.06                  PH
# 3  36.55                  PH
# 4  32.33                  PH

# %%
# creating data dictionary

import_des = {
    "Region": "Geographical area where the data was collected",
    "Product": "Fruit being analyzed",
    "Year": "Year of the recorded price",
    "Month": "Month of the recorded price",
    "Price": "Retail price of the fruit in the specified month and year",
    "Region Abbreviation": "Abbreviation of the region where the data was collected"
}

data_dictionary_retail = pd.DataFrame({
    'Column Name': df_melted.columns,
    'Description': [import_des.get(col, 'Year and Quadrant values') for col in df_melted.columns],
    'Data Type': df_melted.dtypes.values
})

# %%
data_dictionary_retail
# Out:
#            Column Name                                        Description  \
# 0               Region     Geographical area where the data was collected
# 1              Product                               Fruit being analyzed
# 2                 Year                         Year of the recorded price
# 3                Month                        Month of the recorded price
# 4                Price  Retail price of the fruit in the specified mon...
# 5  Region Abbreviation  Abbreviation of the region where the data was ...
#
#   Data Type
# 0    object
# 1    object
# 2    object
# 3    object
# 4   float64
# 5    object

# %%
# Remove the string "FRESH FRUIT" and "1 KG" from the Product column
df_melted['Product'] = df_melted['Product'].str.replace('FRESH FRUIT, ', '')
df_melted['Product'] = df_melted['Product'].str.replace(', 1 KG', '')

# Display the updated dataframe
df_melted.tail(30)
# Out:
#                                      Region                       Product  \
# 52415                            REGION XII    WATERMELON, PAKWAN, MEDIUM
# 52416                           REGION XIII                       AVOCADO
# 52418                           REGION XIII       BANANA, LAKATAN, MEDIUM
# 52419                           REGION XIII      BANANA, LATUNDAN, MEDIUM
# 52422                           REGION XIII     MANGO, CEBU, RIPE, MEDIUM
# 52424                           REGION XIII  MANGO, KALABAW, RIPE, MEDIUM
# 52429                           REGION XIII                PAPAYA, MEDIUM
# 52430                           REGION XIII        PAPAYA, NATIVE, MEDIUM
# 52436                           REGION XIII      PINEAPPLE, PINYA, MEDIUM
# 52442                           REGION XIII                      LANZONES
# 52444                           REGION XIII                POMELO, MEDIUM
# 52448                           REGION XIII              CALAMANSI, LOOSE
# 52451                           REGION XIII    WATERMELON, PAKWAN, MEDIUM
# 52452  AUTONOMOUS REGION IN MUSLIM MINDANAO                       AVOCADO
# 52454  AUTONOMOUS REGION IN MUSLIM MINDANAO       BANANA, LAKATAN, MEDIUM
# 52455  AUTONOMOUS REGION IN MUSLIM MINDANAO      BANANA, LATUNDAN, MEDIUM
# 52456  AUTONOMOUS REGION IN MUSLIM MINDANAO          BANANA, SABA, MEDIUM
# 52457  AUTONOMOUS REGION IN MUSLIM MINDANAO                GUAVA, BAYABAS
# 52458  AUTONOMOUS REGION IN MUSLIM MINDANAO     MANGO, CEBU, RIPE, MEDIUM
# 52459  AUTONOMOUS REGION IN MUSLIM MINDANAO         MANGO, INDIAN, MEDIUM
# 52460  AUTONOMOUS REGION IN MUSLIM MINDANAO  MANGO, KALABAW, RIPE, MEDIUM
# 52463  AUTONOMOUS REGION IN MUSLIM MINDANAO     MANGO, PIKO, RIPE, MEDIUM
# 52465  AUTONOMOUS REGION IN MUSLIM MINDANAO                PAPAYA, MEDIUM
# 52466  AUTONOMOUS REGION IN MUSLIM MINDANAO        PAPAYA, NATIVE, MEDIUM
# 52472  AUTONOMOUS REGION IN MUSLIM MINDANAO      PINEAPPLE, PINYA, MEDIUM
# 52473  AUTONOMOUS REGION IN MUSLIM MINDANAO                        GRAPES
# 52478  AUTONOMOUS REGION IN MUSLIM MINDANAO                      LANZONES
# 52479  AUTONOMOUS REGION IN MUSLIM MINDANAO                      RAMBUTAN
# 52484  AUTONOMOUS REGION IN MUSLIM MINDANAO              CALAMANSI, LOOSE
# 52487  AUTONOMOUS REGION IN MUSLIM MINDANAO    WATERMELON, PAKWAN, MEDIUM
#
#        Year      Month   Price Region Abbreviation
# 52415  2024  September   42.50        SOCCSKSARGEN
# 52416  2024  September  122.00              Caraga
# 52418  2024  September   72.42              Caraga
# 52419  2024  September   37.40              Caraga
# 52422  2024  September  112.50              Caraga
# 52424  2024  September  189.67              Caraga
# 52429  2024  September   53.35              Caraga
# 52430  2024  September   41.88              Caraga
# 52436  2024  September   53.70              Caraga
# 52442  2024  September   91.75              Caraga
# 52444  2024  September  121.56              Caraga
# 52448  2024  September   78.88              Caraga
# 52451  2024  September   28.33              Caraga
# 52452  2024  September   63.38                ARMM
# 52454  2024  September   52.49                ARMM
# 52455  2024  September   35.77                ARMM
# 52456  2024  September   32.75                ARMM
# 52457  2024  September   36.38                ARMM
# 52458  2024  September  127.88                ARMM
# 52459  2024  September   70.75                ARMM
# 52460  2024  September  158.57                ARMM
# 52463  2024  September  105.83                ARMM
# 52465  2024  September   19.94                ARMM
# 52466  2024  September   35.84                ARMM
# 52472  2024  September   87.56                ARMM
# 52473  2024  September  305.00                ARMM
# 52478  2024  September   59.00                ARMM
# 52479  2024  September   60.00                ARMM
# 52484  2024  September   57.57                ARMM
# 52487  2024  September   33.50                ARMM

# %%
# Check for rows with any null values in df_melted
null_rows = df_melted[df_melted.isnull().any(axis=1)]
null_rows
# Out:
# Empty DataFrame
# Columns: [Region, Product, Year, Month, Price, Region Abbreviation]
# Index: []

# %%
# check for nulls
sns.heatmap(df_melted.isnull(), cbar=False, yticklabels=False)
plt.title('Heatmap of null values in DataFrame')
plt.show()

# %% [markdown]
#     There are no more null rows with the melted df

# %%
# Check for duplicates in the dataframe
duplicates = df_melted[df_melted.duplicated()]
duplicates
# Out:
# Empty DataFrame
# Columns: [Region, Product, Year, Month, Price, Region Abbreviation]
# Index: []

# %%
# Check for duplicates in the dataframe
duplicates = df_melted[df_melted.duplicated()]

# Create a heatmap to visualize the duplicates
sns.heatmap(df_melted.isin(duplicates).astype(int), cbar=False, cmap='viridis', yticklabels=False)
plt.title('Heatmap of Duplicates in DataFrame')
plt.show()

# %% [markdown]
#     There are no duplicated values

# %% [markdown]
# ### 3. Exploratory Data Analysis
# <a id="eda"></a> <br>

# %%
# Data Frame for PH (overall)

df_ph = df_melted[df_melted['Region'] == 'PHILIPPINES']
df_ph
# Out:
#             Region                       Product  Year      Month   Price  \
# 0      PHILIPPINES                       AVOCADO  2018    January   63.90
# 1      PHILIPPINES       BANANA, CARDAVA, MEDIUM  2018    January   26.68
# 2      PHILIPPINES       BANANA, LAKATAN, MEDIUM  2018    January   52.06
# 3      PHILIPPINES      BANANA, LATUNDAN, MEDIUM  2018    January   36.55
# 4      PHILIPPINES          BANANA, SABA, MEDIUM  2018    January   32.33
# ...            ...                           ...   ...        ...     ...
# 51871  PHILIPPINES  MANDARIN, DALANGHITA, MEDIUM  2024  September   73.26
# 51872  PHILIPPINES              CALAMANSI, LOOSE  2024  September   80.70
# 51873  PHILIPPINES  APPLE, RED DELICIOUS, MEDIUM  2024  September  126.85
# 51874  PHILIPPINES     CANTALOUPE, MELON, MEDIUM  2024  September   59.13
# 51875  PHILIPPINES    WATERMELON, PAKWAN, MEDIUM  2024  September   53.46
#
#       Region Abbreviation
# 0                      PH
# 1                      PH
# 2                      PH
# 3                      PH
# 4                      PH
# ...                   ...
# 51871                  PH
# 51872                  PH
# 51873                  PH
# 51874                  PH
# 51875                  PH
#
# [2916 rows x 6 columns]

# %%
# Data Frame for Regions (exlcuding PH)

df_regions = df_melted[df_melted['Region'] != 'PHILIPPINES']
df_regions
# Out:
#                                      Region                       Product  \
# 36                  National Capital Region                       AVOCADO
# 38                  National Capital Region       BANANA, LAKATAN, MEDIUM
# 44                  National Capital Region  MANGO, KALABAW, RIPE, MEDIUM
# 56                  National Capital Region      PINEAPPLE, PINYA, MEDIUM
# 57                  National Capital Region                        GRAPES
# ...                                     ...                           ...
# 52473  AUTONOMOUS REGION IN MUSLIM MINDANAO                        GRAPES
# 52478  AUTONOMOUS REGION IN MUSLIM MINDANAO                      LANZONES
# 52479  AUTONOMOUS REGION IN MUSLIM MINDANAO                      RAMBUTAN
# 52484  AUTONOMOUS REGION IN MUSLIM MINDANAO              CALAMANSI, LOOSE
# 52487  AUTONOMOUS REGION IN MUSLIM MINDANAO    WATERMELON, PAKWAN, MEDIUM
#
#        Year      Month   Price Region Abbreviation
# 36     2018    January  157.40                 NCR
# 38     2018    January   66.96                 NCR
# 44     2018    January  168.49                 NCR
# 56     2018    January   58.23                 NCR
# 57     2018    January  251.95                 NCR
# ...     ...        ...     ...                 ...
# 52473  2024  September  305.00                ARMM
# 52478  2024  September   59.00                ARMM
# 52479  2024  September   60.00                ARMM
# 52484  2024  September   57.57                ARMM
# 52487  2024  September   33.50                ARMM
#
# [20574 rows x 6 columns]

# %%
df_regions['Price'].describe()
# Out:
# count    20574.000000
# mean        82.850440
# std         62.193338
# min         14.230000
# 25%         42.830000
# 50%         61.595000
# 75%         99.130000
# max        380.440000
# Name: Price, dtype: float64

# %%
df_ph['Price'].describe()
# Out:
# count    2916.000000
# mean       87.227905
# std        61.179023
# min        20.240000
# 25%        48.042500
# 50%        65.905000
# 75%       103.322500
# max       322.710000
# Name: Price, dtype: float64

# %% [markdown]
# #### Philippines

# %%
# Filter the data for the specified products
products_of_interest = ['MANGO, NATIVE, MEDIUM', 'GRAPES, SEEDLESS', 'AVOCADO']
filtered_df = df_ph[df_ph['Product'].isin(products_of_interest)]

# Function to calculate IQR and identify outliers
def calculate_iqr_and_outliers(df, product_name):
    product_df = df[df['Product'] == product_name]
    Q1 = product_df['Price'].quantile(0.25)
    Q3 = product_df['Price'].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = product_df[(product_df['Price'] < lower_bound) | (product_df['Price'] > upper_bound)]
    return Q1, Q3, IQR, lower_bound, upper_bound, outliers

# Calculate IQR and identify outliers for each product
iqr_results = {}
for product in products_of_interest:
    Q1, Q3, IQR, lower_bound, upper_bound, outliers = calculate_iqr_and_outliers(filtered_df, product)
    iqr_results[product] = {
        'Q1': Q1,
        'Q3': Q3,
        'IQR': IQR,
        'Lower Bound': lower_bound,
        'Upper Bound': upper_bound,
        'Outliers': outliers
    }

import matplotlib.pyplot as plt
import seaborn as sns

# Set up the matplotlib figure
plt.figure(figsize=(12, 8))

# Create a box plot for each product
for i, product in enumerate(products_of_interest, 1):
    plt.subplot(1, len(products_of_interest), i)
    sns.boxplot(x='Product', y='Price', data=filtered_df[filtered_df['Product'] == product])
    plt.title(f'Box Plot for {product}')
    plt.xlabel('Product')
    plt.ylabel('Price')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Regions

# %%
# Filter the data for the specified products
products_of_interest = ['MANGO, NATIVE, MEDIUM', 'GRAPES, SEEDLESS', 'AVOCADO']
filtered_df = df_regions[df_regions['Product'].isin(products_of_interest)]

# Function to calculate IQR and identify outliers
def calculate_iqr_and_outliers(df, product_name):
    product_df = df[df['Product'] == product_name]
    Q1 = product_df['Price'].quantile(0.25)
    Q3 = product_df['Price'].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = product_df[(product_df['Price'] < lower_bound) | (product_df['Price'] > upper_bound)]
    return Q1, Q3, IQR, lower_bound, upper_bound, outliers

# Calculate IQR and identify outliers for each product
iqr_results = {}
for product in products_of_interest:
    Q1, Q3, IQR, lower_bound, upper_bound, outliers = calculate_iqr_and_outliers(filtered_df, product)
    iqr_results[product] = {
        'Q1': Q1,
        'Q3': Q3,
        'IQR': IQR,
        'Lower Bound': lower_bound,
        'Upper Bound': upper_bound,
        'Outliers': outliers
    }

import matplotlib.pyplot as plt
import seaborn as sns

# Set up the matplotlib figure
plt.figure(figsize=(12, 8))

# Create a box plot for each product
for i, product in enumerate(products_of_interest, 1):
    plt.subplot(1, len(products_of_interest), i)
    sns.boxplot(x='Product', y='Price', data=filtered_df[filtered_df['Product'] == product])
    plt.title(f'Box Plot for {product}')
    plt.xlabel('Product')
    plt.ylabel('Price')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Outlier Detection (PH)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Function to calculate IQR and identify outliers for each region
def calculate_iqr_and_outliers(df, region_name):
    region_df = df[df['Region'] == region_name]
    Q1 = region_df['Price'].quantile(0.25)
    Q3 = region_df['Price'].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = region_df[(region_df['Price'] < lower_bound) | (region_df['Price'] > upper_bound)]
    return Q1, Q3, IQR, lower_bound, upper_bound, outliers

# Get unique regions
regions = df_ph['Region'].unique()

# Calculate IQR and identify outliers for each region
iqr_results = {}
for region in regions:
    Q1, Q3, IQR, lower_bound, upper_bound, outliers = calculate_iqr_and_outliers(df_ph, region)
    iqr_results[region] = {
        'Q1': Q1,
        'Q3': Q3,
        'IQR': IQR,
        'Lower Bound': lower_bound,
        'Upper Bound': upper_bound,
        'Outliers': outliers
    }

# Combine all outliers into a single DataFrame for visualization
all_outliers = pd.concat([result['Outliers'] for result in iqr_results.values()])

# Visualize the outliers using a box plot with a slimmer figure size
plt.figure(figsize=(10, 6))  # Adjusted size for a slimmer plot
sns.boxplot(x='Region', y='Price', data=df_ph)
sns.scatterplot(x='Region', y='Price', data=all_outliers, color='red', label='Outliers', s=50)
plt.xticks(rotation=90)
plt.title('Box Plot of Prices by Region with Outliers')
plt.xlabel('Region')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# #### Outlier Detection (Regions)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Function to calculate IQR and identify outliers for each region
def calculate_iqr_and_outliers(df, region_name):
    region_df = df[df['Region'] == region_name]
    Q1 = region_df['Price'].quantile(0.25)
    Q3 = region_df['Price'].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = region_df[(region_df['Price'] < lower_bound) | (region_df['Price'] > upper_bound)]
    return Q1, Q3, IQR, lower_bound, upper_bound, outliers

# Get unique regions
regions = df_regions['Region'].unique()

# Calculate IQR and identify outliers for each region
iqr_results = {}
for region in regions:
    Q1, Q3, IQR, lower_bound, upper_bound, outliers = calculate_iqr_and_outliers(df_regions, region)
    iqr_results[region] = {
        'Q1': Q1,
        'Q3': Q3,
        'IQR': IQR,
        'Lower Bound': lower_bound,
        'Upper Bound': upper_bound,
        'Outliers': outliers
    }

# Combine all outliers into a single DataFrame for visualization
all_outliers = pd.concat([result['Outliers'] for result in iqr_results.values()])

# Visualize the outliers using a box plot with a slimmer figure size
plt.figure(figsize=(10, 6))  # Adjusted size for a slimmer plot
sns.boxplot(x='Region', y='Price', data=df_regions)
sns.scatterplot(x='Region', y='Price', data=all_outliers, color='red', label='Outliers', s=50)
plt.xticks(rotation=90)
plt.title('Box Plot of Prices by Region with Outliers')
plt.xlabel('Region')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
#     Medj di applicable yung detection of outliers per region kasi hindi comparable yung two fruits (e.g. banana vs. grapes).

# %% [markdown]
# #### Distribution of Prices (PH)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram of prices
plt.figure(figsize=(8, 5))
sns.histplot(data=df_ph, x='Price', bins=50, kde=True, color='blue')
plt.title('Distribution of Prices in PH')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# Boxplot of prices
plt.figure(figsize=(8, 5))
sns.boxplot(data=df_ph, x='Price', color='skyblue')
plt.title('Boxplot of Prices in PH')
plt.xlabel('Price')
plt.show()

# %% [markdown]
# #### Distribution of Prices (Regions)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram of prices
plt.figure(figsize=(8, 5))
sns.histplot(data=df_ph, x='Price', bins=30, kde=True, color='blue')
plt.title('Distribution of Prices (Regions)')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# Boxplot of prices
plt.figure(figsize=(8, 5))
sns.boxplot(data=df_ph, x='Price', color='skyblue')
plt.title('Boxplot of Prices (Regions)')
plt.xlabel('Price')
plt.show()

# %% [markdown]
# #### Price Trends Over Time (PH)

# %%
# Line plot of average prices over years
avg_price_year = df_ph.groupby('Year')['Price'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(data=avg_price_year, x='Year', y='Price', marker='o')
plt.title('Average Prices Over Years (PH)')
plt.xlabel('Year')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.show()

# Line plot of average prices by months
avg_price_month = df_melted.groupby('Month')['Price'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(data=avg_price_month, x='Month', y='Price', marker='o', color='green')
plt.title('Average Prices by Month (PH)')
plt.xlabel('Month')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Price Trends Over Time (Regions)

# %%
# Line plot of average prices over years
avg_price_year = df_regions.groupby('Year')['Price'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(data=avg_price_year, x='Year', y='Price', marker='o')
plt.title('Average Prices Over Years (Regions)')
plt.xlabel('Year')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.show()

# Line plot of average prices by months
avg_price_month = df_regions.groupby('Month')['Price'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(data=avg_price_month, x='Month', y='Price', marker='o', color='green')
plt.title('Average Prices by Month (Regions)')
plt.xlabel('Month')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Highest Prices

# %%
# Calculate the average price per region
df_regional_price_ave = df_regions.groupby('Region')['Price'].mean().reset_index()

# Rename the columns for clarity
df_regional_price_ave.columns = ['Region', 'Average Price']

# Sort the DataFrame by 'Average Price' in descending order
df_regional_price_ave = df_regional_price_ave.sort_values(by='Average Price', ascending=False)

# Display the resulting DataFrame
df_regional_price_ave
# Out:
#                                   Region  Average Price
# 3                National Capital Region     135.736893
# 6                             REGION III     112.745825
# 10                             REGION VI     105.954728
# 4                               REGION I     101.332708
# 7                            REGION IV-A      95.035453
# 2                        MIMAROPA REGION      89.531407
# 5                              REGION II      86.803870
# 0   AUTONOMOUS REGION IN MUSLIM MINDANAO      81.446282
# 12                           REGION VIII      75.642562
# 1       Cordillera Administrative Region      75.616014
# 9                               REGION V      73.607086
# 15                            REGION XII      69.138460
# 16                           REGION XIII      68.510885
# 11                            REGION VII      65.639125
# 8                              REGION IX      58.873385
# 14                             REGION XI      57.662681
# 13                              REGION X      54.113111

# %%
import seaborn as sns

# Import necessary libraries
import matplotlib.pyplot as plt

# Ensure the DataFrame is sorted by 'Average Price' for a better visual comparison
df_regional_price_ave_sorted = df_regional_price_ave.sort_values(by='Average Price', ascending=False)

# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Initialize the matplotlib figure
plt.figure(figsize=(14, 8))

# Create a horizontal bar plot
sns.barplot(
    x='Average Price',
    y='Region',
    data=df_regional_price_ave_sorted,
    palette='viridis',
    edgecolor='black'
)

# Add a title and labels
plt.title('Average Fruit Prices by Region', fontsize=16, weight='bold')
plt.xlabel('Average Price', fontsize=14)
plt.ylabel('Region', fontsize=14)

# Add value labels to each bar for clarity
for index, value in enumerate(df_regional_price_ave_sorted['Average Price']):
    plt.text(
        value + 0.5,  # Position text slightly to the right of the bar
        index, 
        f'{value:.2f}', 
        va='center',
        fontsize=12
    )

# Adjust layout for better fit
plt.tight_layout()

# Display the plot
plt.show()

# %%
from plotly.subplots import make_subplots
import plotly.graph_objs as go
import plotly.colors

# Define a color palette with 17 different colors
colors = plotly.colors.qualitative.Dark24[:17]

# Convert 'Year' and 'Month' columns to a datetime column
df_regions['Date'] = pd.to_datetime(df_regions['Year'] + '-' + df_regions['Month'] + '-01')

# Group by 'Region' and 'Date' to calculate the average price for each region over time
avg_price_region_time = df_regions.groupby(['Region', 'Date'])['Price'].mean().reset_index()

# Create a figure with subplots
fig = make_subplots(rows=1, cols=1)

# Iterate through each region and add a trace for the average price trend
for i, region in enumerate(df_regions['Region'].unique()):
    region_data = avg_price_region_time[avg_price_region_time['Region'] == region]
    fig.add_trace(go.Scatter(
        x=region_data['Date'],
        y=region_data['Price'],
        mode='lines+markers',
        name=region,
        line=dict(color=colors[i % len(colors)])
    ))

# Update layout
fig.update_layout(
    title='Average Fruit Prices Over Time by Region',
    xaxis_title='Date',
    yaxis_title='Average Price',
    legend_title='Region',
    xaxis=dict(tickangle=45),
    width=1200,  # Set the width of the figure
    height=800   # Set the height of the figure
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="36a02217-8a52-47a2-bed4-c931f6cdc14b" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36a02217-8a52-47a2-bed4-c931f6cdc14b")) {                    Plotly.newPlot(                        "36a02217-8a52-47a2-bed4-c931f6cdc14b",                        [{"line":{"color":"#2E91E5"},"mode":"lines+markers","name":"National Capital Region","x":["2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00","2022-07-01T00:00:00","2022-08-01T00:00:00","2022-09-01T00:00:00","2022-10-01T00:00:00","2022-11-01T00:00:00","2022-12-01T00:00:00","2023-01-01T00:00:00","2023-02-01T00:00:00","2023-03-01T00:00:00","2023-04-01T00:00:00","2023-05-01T00:00:00","2023-06-01T00:00:00","2023-07-01T00:00:00","2023-08-01T00:00:00","2023-09-01T00:00:00","2023-10-01T00:00:00","2023-11-01T00:00:00","2023-12-01T00:00:00","2024-01-01T00:00:00","2024-02-01T00:00:00","2024-03-01T00:00:00","2024-04-01T00:00:00","2024-05-01T00:00:00","2024-06-01T00:00:00","2024-07-01T00:00:00","2024-08-01T00:00:00","2024-09-01T00:00:00"],"y":[126.93666666666667,134.85833333333332,134.17666666666668,131.44000000000003,120.34333333333332,116.21666666666665,112.105,117.97666666666667,122.70666666666666,123.61,127.79833333333333,129.57833333333335,127.00666666666666,124.54666666666667,129.04166666666666,136.005,135.22166666666666,125.73666666666668,120.35166666666667,124.855,129.22166666666666,137.76833333333332,134.20000000000002,136.74666666666667,132.59,134.09666666666666,148.29166666666666,148.08333333333334,140.67666666666665,130.83833333333334,124.82333333333334,125.96166666666666,133.73166666666665,132.53166666666667,131.25,131.065,146.415,147.84333333333333,139.58166666666668,135.02333333333334,131.96333333333334,122.74333333333334,120.97666666666667,115.79333333333334,120.97666666666667,120.015,126.02833333333332,127.11,130.46833333333333,130.975,133.735,133.41666666666666,129.60333333333332,128.71833333333333,126.33166666666666,128.00666666666666,132.48166666666665,137.43833333333333,144.615,146.62166666666667,148.035,142.53666666666666,147.02666666666667,149.495,144.08333333333334,138.64333333333335,134.115,135.795,143.76166666666666,148.91666666666666,154.915,161.005,158.54833333333332,159.245,157.9466666666667,151.695,154.15,151.24666666666667,154.38833333333332,158.97666666666666,170.89333333333335],"type":"scatter"},{"line":{"color":"#E15F99"},"mode":"lines+markers","name":"Cordillera Administrative Region","x":["2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018- ...

# %% [markdown]
# #### Regional Price Comparison

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_regions, x='Region Abbreviation', y='Price', palette='Set3')
plt.title('Price Distribution by Region')
plt.xlabel('Region')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Top Products by Average Price (PH)

# %%
top_products = df_ph.groupby('Product')['Price'].mean().sort_values(ascending=False).head(10).reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(data=top_products, x='Price', y='Product', palette='Blues_r')
plt.title('Top 10 Products by Average Price')
plt.xlabel('Average Price')
plt.ylabel('Product')
plt.show()

# %% [markdown]
# ### 4. Data Preparation

# %%
df_melted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23490 entries, 0 to 52487
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Region               23490 non-null  object
#  1   Product              23490 non-null  object
#  2   Year                 23490 non-null  object
#  3   Month                23490 non-null  object
#  4   Price                23490 non-null  float64
#  5   Region Abbreviation  23490 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 1.3+ MB

# %%
# Adding region abbreviation column + extracting ABV from 'Region' column

df_regions['Region Abbreviation'] = df_regions['Region'].str.extract(r'\((.*?)\)')

df_regions['Region'] = df_regions['Region'].str.replace(r'\(.*?\)', '', regex=True).str.strip()

df_regions.head()
# Out:
#                      Region                       Product  Year    Month  \
# 36  National Capital Region                       AVOCADO  2018  January
# 38  National Capital Region       BANANA, LAKATAN, MEDIUM  2018  January
# 44  National Capital Region  MANGO, KALABAW, RIPE, MEDIUM  2018  January
# 56  National Capital Region      PINEAPPLE, PINYA, MEDIUM  2018  January
# 57  National Capital Region                        GRAPES  2018  January
#
#      Price Region Abbreviation       Date
# 36  157.40                 NaN 2018-01-01
# 38   66.96                 NaN 2018-01-01
# 44  168.49                 NaN 2018-01-01
# 56   58.23                 NaN 2018-01-01
# 57  251.95                 NaN 2018-01-01

# %%
# Retrieving the specific month in a year where the price of a fruit was the highest & the month where it was the lowest

# Convert the 'Price' column to numeric, just in case
df_regions['Price'] = pd.to_numeric(df_regions['Price'], errors='coerce')

# Group the data by 'Region', 'Product', and 'Year'
# Find the month with the maximum and minimum prices for each product in each region and year
max_min_price_per_fruit = df_regions.groupby(['Region', 'Product', 'Year']).apply(
    lambda x: pd.Series({
        'Max Month': x.loc[x['Price'].idxmax(), 'Month'],  # Month with highest price
        'Max Price': x['Price'].max(),                    # Maximum price
        'Min Month': x.loc[x['Price'].idxmin(), 'Month'],  # Month with lowest price
        'Min Price': x['Price'].min()                     # Minimum price
    })
).reset_index()

# Display the result
max_min_price_per_fruit
# Out:
#                                     Region                     Product  Year  \
# 0     AUTONOMOUS REGION IN MUSLIM MINDANAO                     AVOCADO  2018
# 1     AUTONOMOUS REGION IN MUSLIM MINDANAO                     AVOCADO  2019
# 2     AUTONOMOUS REGION IN MUSLIM MINDANAO                     AVOCADO  2020
# 3     AUTONOMOUS REGION IN MUSLIM MINDANAO                     AVOCADO  2021
# 4     AUTONOMOUS REGION IN MUSLIM MINDANAO                     AVOCADO  2022
# ...                                    ...                         ...   ...
# 1773                           REGION XIII  WATERMELON, PAKWAN, MEDIUM  2020
# 1774                           REGION XIII  WATERMELON, PAKWAN, MEDIUM  2021
# 1775                           REGION XIII  WATERMELON, PAKWAN, MEDIUM  2022
# 1776                           REGION XIII  WATERMELON, PAKWAN, MEDIUM  2023
# 1777                           REGION XIII  WATERMELON, PAKWAN, MEDIUM  2024
#
#      Max Month  Max Price  Min Month  Min Price
# 0        March      52.82    October      48.17
# 1     November      53.11        May      47.99
# 2       August      67.86      March      52.00
# 3        March      68.49   December      65.39
# 4         June      68.88    October      57.68
# ...        ...        ...        ...        ...
# 1773       May      29.83    January      26.19
# 1774   January      30.55  September      24.17
# 1775      July      35.00        May      27.50
# 1776  February      41.67       June      28.83
# 1777  February      38.33        May      22.50
#
# [1778 rows x 7 columns]

# %%
# Aggregating the price of a product from a certain region, in a specific year
# Eg. In 2018, the average price of an avocado in ARMM during the Dry Season was X, while the price during the Rainy Season was Y

season_mapping = {
    'January': 'Dry', 'February': 'Dry', 'March': 'Dry', 'April': 'Dry', 'May': 'Dry',
    'June': 'Rainy', 'July': 'Rainy', 'August': 'Rainy', 'September': 'Rainy',
    'October': 'Rainy', 'November': 'Rainy', 'December': 'Dry'
}

# Add a 'Season' column to the DataFrame
df_regions['Season'] = df_regions['Month'].map(season_mapping)

# Now, group by Region, Product, Year, and Season to get the average price
seasonal_prices = df_regions.groupby(['Region', 'Product', 'Year', 'Season'])['Price'].mean().reset_index()

# Display the result to inspect
seasonal_prices
# Out:
#                                     Region                     Product  Year  \
# 0     AUTONOMOUS REGION IN MUSLIM MINDANAO                     AVOCADO  2018
# 1     AUTONOMOUS REGION IN MUSLIM MINDANAO                     AVOCADO  2018
# 2     AUTONOMOUS REGION IN MUSLIM MINDANAO                     AVOCADO  2019
# 3     AUTONOMOUS REGION IN MUSLIM MINDANAO                     AVOCADO  2019
# 4     AUTONOMOUS REGION IN MUSLIM MINDANAO                     AVOCADO  2020
# ...                                    ...                         ...   ...
# 3551                           REGION XIII  WATERMELON, PAKWAN, MEDIUM  2022
# 3552                           REGION XIII  WATERMELON, PAKWAN, MEDIUM  2023
# 3553                           REGION XIII  WATERMELON, PAKWAN, MEDIUM  2023
# 3554                           REGION XIII  WATERMELON, PAKWAN, MEDIUM  2024
# 3555                           REGION XIII  WATERMELON, PAKWAN, MEDIUM  2024
#
#      Season      Price
# 0       Dry  50.786667
# 1     Rainy  49.996667
# 2       Dry  49.890000
# 3     Rainy  51.665000
# 4       Dry  57.180000
# ...     ...        ...
# 3551  Rainy  31.778333
# 3552    Dry  39.305000
# 3553  Rainy  32.666667
# 3554    Dry  33.166000
# 3555  Rainy  28.875000
#
# [3556 rows x 5 columns]

# %%
# Comparison of the average price of a fruit during the rainy and dry season (difference)

dry_vs_rainy_yearly = seasonal_prices.pivot_table(index=['Region', 'Product', 'Year'], 
                                                  columns='Season', values='Price').reset_index()

dry_vs_rainy_yearly['Yearly Average'] = dry_vs_rainy_yearly[['Dry', 'Rainy']].mean(axis=1)

dry_vs_rainy_yearly['Difference (Dry - Rainy)'] = dry_vs_rainy_yearly['Dry'] - dry_vs_rainy_yearly['Rainy']

dry_vs_rainy_yearly
# Out:
# Season                                Region                     Product  \
# 0       AUTONOMOUS REGION IN MUSLIM MINDANAO                     AVOCADO
# 1       AUTONOMOUS REGION IN MUSLIM MINDANAO                     AVOCADO
# 2       AUTONOMOUS REGION IN MUSLIM MINDANAO                     AVOCADO
# 3       AUTONOMOUS REGION IN MUSLIM MINDANAO                     AVOCADO
# 4       AUTONOMOUS REGION IN MUSLIM MINDANAO                     AVOCADO
# ...                                      ...                         ...
# 1773                             REGION XIII  WATERMELON, PAKWAN, MEDIUM
# 1774                             REGION XIII  WATERMELON, PAKWAN, MEDIUM
# 1775                             REGION XIII  WATERMELON, PAKWAN, MEDIUM
# 1776                             REGION XIII  WATERMELON, PAKWAN, MEDIUM
# 1777                             REGION XIII  WATERMELON, PAKWAN, MEDIUM
#
# Season  Year        Dry      Rainy  Yearly Average  Difference (Dry - Rainy)
# 0       2018  50.786667  49.996667       50.391667                  0.790000
# 1       2019  49.890000  51.665000       50.777500                 -1.775000
# 2       2020  57.180000  66.830000       62.005000                 -9.650000
# 3       2021  66.990000  67.318333       67.154167                 -0.328333
# 4       2022  65.656667  62.830000       64.243333                  2.826667
# ...      ...        ...        ...             ...                       ...
# 1773    2020  28.433333  28.918333       28.675833                 -0.485000
# 1774    2021  29.070000  25.861667       27.465833                  3.208333
# 1775    2022  30.500000  31.778333       31.139167                 -1.278333
# 1776    2023  39.305000  32.666667       35.985833                  6.638333
# 1777    2024  33.166000  28.875000       31.020500                  4.291000
#
# [1778 rows x 7 columns]

# %%
# Group by Region and Product, and calculate the average (mean) across all years (2018-2023/2024)
dry_vs_rainy_aggregated = dry_vs_rainy_yearly.groupby(['Region', 'Product']).agg({
    'Dry': 'mean',
    'Rainy': 'mean',
    'Yearly Average': 'mean',
    'Difference (Dry - Rainy)': 'mean'
}).reset_index()

# Display the resulting DataFrame
dry_vs_rainy_aggregated
# Out:
# Season                                Region                     Product  \
# 0       AUTONOMOUS REGION IN MUSLIM MINDANAO                     AVOCADO
# 1       AUTONOMOUS REGION IN MUSLIM MINDANAO     BANANA, LAKATAN, MEDIUM
# 2       AUTONOMOUS REGION IN MUSLIM MINDANAO    BANANA, LATUNDAN, MEDIUM
# 3       AUTONOMOUS REGION IN MUSLIM MINDANAO        BANANA, SABA, MEDIUM
# 4       AUTONOMOUS REGION IN MUSLIM MINDANAO            CALAMANSI, LOOSE
# ..                                       ...                         ...
# 249                              REGION XIII              PAPAYA, MEDIUM
# 250                              REGION XIII      PAPAYA, NATIVE, MEDIUM
# 251                              REGION XIII    PINEAPPLE, PINYA, MEDIUM
# 252                              REGION XIII              POMELO, MEDIUM
# 253                              REGION XIII  WATERMELON, PAKWAN, MEDIUM
#
# Season        Dry      Rainy  Yearly Average  Difference (Dry - Rainy)
# 0       60.040619  60.547262       60.293940                 -0.506643
# 1       51.957524  51.954643       51.956083                  0.002881
# 2       35.738143  35.235833       35.486988                  0.502310
# 3       31.579619  32.045595       31.812607                 -0.465976
# 4       77.067095  72.495476       74.781286                  4.571619
# ..            ...        ...             ...                       ...
# 249     43.656810  44.214524       43.935667                 -0.557714
# 250     37.381857  37.358690       37.370274                  0.023167
# 251     46.053238  46.185714       46.119476                 -0.132476
# 252     84.750000  89.246429       86.998214                 -4.496429
# 253     30.419905  28.521667       29.470786                  1.898238
#
# [254 rows x 6 columns]

# %%
# Top products per region with large differences in dry vs rainy season


# First, take the absolute value of the difference to rank based on the magnitude of the difference
dry_vs_rainy_aggregated['Abs Difference'] = dry_vs_rainy_aggregated['Difference (Dry - Rainy)'].abs()

# Now, for each region, find the top 10 products with the greatest difference
top_10_products_per_region = dry_vs_rainy_aggregated.groupby('Region').apply(
    lambda x: x.nlargest(10, 'Abs Difference')
).reset_index(drop=True)

# Drop the 'Difference (Dry - Rainy)' column
top_10_products_per_region = top_10_products_per_region.drop(columns=['Difference (Dry - Rainy)'])

# Create a new column to specify whether it's more expensive during the Dry or Rainy season
top_10_products_per_region['More Expensive In'] = top_10_products_per_region.apply(
    lambda row: 'Dry' if row['Dry'] > row['Rainy'] else 'Rainy', axis=1
)

# Display the resulting DataFrame
top_10_products_per_region
# Out:
# Season                                Region                       Product  \
# 0       AUTONOMOUS REGION IN MUSLIM MINDANAO     MANGO, CEBU, RIPE, MEDIUM
# 1       AUTONOMOUS REGION IN MUSLIM MINDANAO              CALAMANSI, LOOSE
# 2       AUTONOMOUS REGION IN MUSLIM MINDANAO     MANGO, PIKO, RIPE, MEDIUM
# 3       AUTONOMOUS REGION IN MUSLIM MINDANAO         MANGO, INDIAN, MEDIUM
# 4       AUTONOMOUS REGION IN MUSLIM MINDANAO    WATERMELON, PAKWAN, MEDIUM
# ..                                       ...                           ...
# 161                              REGION XIII              CALAMANSI, LOOSE
# 162                              REGION XIII  MANGO, KALABAW, RIPE, MEDIUM
# 163                              REGION XIII                PAPAYA, MEDIUM
# 164                              REGION XIII       BANANA, LAKATAN, MEDIUM
# 165                              REGION XIII      BANANA, LATUNDAN, MEDIUM
#
# Season         Dry       Rainy  Yearly Average  Abs Difference  \
# 0       125.434476  118.844881      122.139679        6.589595
# 1        77.067095   72.495476       74.781286        4.571619
# 2       106.103286  103.478810      104.791048        2.624476
# 3        66.249476   63.730476       64.989976        2.519000
# 4        25.738000   27.225000       26.481500        1.487000
# ..             ...         ...             ...             ...
# 161      78.073667   76.204167       77.138917        1.869500
# 162     126.282762  124.582024      125.432393        1.700738
# 163      43.656810   44.214524       43.935667        0.557714
# 164      51.712810   52.027143       51.869976        0.314333
# 165      33.393381   33.611548       33.502464        0.218167
#
# Season More Expensive In
# 0                    Dry
# 1                    Dry
# 2                    Dry
# 3                    Dry
# 4                  Rainy
# ..                   ...
# 161                  Dry
# 162                  Dry
# 163                Rainy
# 164                Rainy
# 165                Rainy
#
# [166 rows x 7 columns]

# %% [markdown]
# ## Time Series Analysis

# %%
# Get unique products
products = df_ph['Product'].unique()

# Dictionary to store forecasts
forecasts = {}

# Iterate through each product to fit the SARIMAX model and make predictions
for product in products:
  # Filter the data for the specific product and region
  df_filtered = df_ph[(df_ph['Product'] == product) & (df_ph['Region'] == 'PHILIPPINES')]

  # Convert the 'Year' and 'Month' columns to a datetime index
  df_filtered['Date'] = pd.to_datetime(df_filtered['Year'] + '-' + df_filtered['Month'] + '-01')
  df_filtered.set_index('Date', inplace=True)

  # Sort the dataframe by date
  df_filtered.sort_index(inplace=True)

  # Fit the SARIMA model
  model = SARIMAX(df_filtered['Price'], order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
  results = model.fit()

  # Forecast future prices for October, November, December 2024, and the whole of 2025
  forecast = results.get_forecast(steps=15)
  forecast_df = forecast.conf_int()
  forecast_df['Forecast'] = results.predict(start=forecast_df.index[0], end=forecast_df.index[-1])

  # Store the forecast in the dictionary
  forecasts[product] = forecast_df

# Create a new dataframe to store the predictions
predictions = []

for product, forecast_df in forecasts.items():
  for date, row in forecast_df.iterrows():
    predictions.append({
      'Product': product,
      'Date': date,
      'Forecast': row['Forecast'],
      'Lower CI': row['lower Price'],
      'Upper CI': row['upper Price']
    })

predictions_df = pd.DataFrame(predictions)

# Format the date to "Month Year"
predictions_df['Date'] = predictions_df['Date'].dt.strftime('%B %Y')

# Filter the predictions for October 2024, November 2024, December 2024, and the whole of 2025
predictions_df = predictions_df[predictions_df['Date'].str.contains('2024')]

# Display the resulting dataframe
predictions_df
# Out:
#                         Product           Date    Forecast    Lower CI  \
# 0                       AVOCADO   October 2024  121.561968  116.264114
# 1                       AVOCADO  November 2024  127.694313  118.674610
# 2                       AVOCADO  December 2024  132.308651  121.298540
# 15      BANANA, CARDAVA, MEDIUM   October 2024   29.298812   26.062470
# 16      BANANA, CARDAVA, MEDIUM  November 2024   28.779141   24.333155
# ..                          ...            ...         ...         ...
# 511   CANTALOUPE, MELON, MEDIUM  November 2024   58.299727   46.469251
# 512   CANTALOUPE, MELON, MEDIUM  December 2024   58.297873   43.637703
# 525  WATERMELON, PAKWAN, MEDIUM   October 2024   53.666424   50.941440
# 526  WATERMELON, PAKWAN, MEDIUM  November 2024   53.718432   50.137899
# 527  WATERMELON, PAKWAN, MEDIUM  December 2024   54.564976   50.396630
#
#        Upper CI
# 0    126.859823
# 1    136.714015
# 2    143.318762
# 15    32.535153
# 16    33.225128
# ..          ...
# 511   70.130203
# 512   72.958044
# 525   56.391408
# 526   57.298966
# 527   58.733322
#
# [108 rows x 5 columns]

# %%
# Combine actual and forecast data for 2024
actual_2024 = df_ph[(df_ph['Year'] == '2024') & (df_ph['Month'].isin(['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September']))]
forecast_2024 = predictions_df[predictions_df['Date'].str.contains('2024')]

# Convert 'Month' and 'Year' to datetime for actual data
actual_2024['Date'] = pd.to_datetime(actual_2024['Year'] + '-' + actual_2024['Month'] + '-01')
forecast_2024['Date'] = pd.to_datetime(forecast_2024['Date'], format='%B %Y')

# Calculate the change in value for each product
actual_2024['Change'] = actual_2024.groupby('Product')['Price'].diff()

# Get the top 5 products with the highest change in value
top_5_changes = actual_2024.nlargest(5, 'Change')

top_5_changes
# Out:
#             Region                       Product  Year      Month   Price  \
# 51848  PHILIPPINES  MANGO, KALABAW, RIPE, MEDIUM  2024  September  183.75
# 51846  PHILIPPINES     MANGO, CEBU, RIPE, MEDIUM  2024  September  156.31
# 50554  PHILIPPINES   MANGO, NATIVE, RIPE, MEDIUM  2024       July   88.54
# 51851  PHILIPPINES     MANGO, PIKO, RIPE, MEDIUM  2024  September  167.08
# 48621  PHILIPPINES                        GRAPES  2024      April  322.71
#
#       Region Abbreviation       Date  Change
# 51848                  PH 2024-09-01   38.96
# 51846                  PH 2024-09-01   34.49
# 50554                  PH 2024-07-01   32.77
# 51851                  PH 2024-09-01   32.08
# 48621                  PH 2024-04-01   27.29

# %%
# Assign unique colors to each product
colors = plt.cm.get_cmap('tab10', len(top_5_changes['Product'].unique()))
color_dict = {product: colors(i) for i, product in enumerate(top_5_changes['Product'].unique())}

# Plot the data
plt.figure(figsize=(12, 6))

# Plot actual prices for top 5 products
for product in top_5_changes['Product'].unique():
  product_actual = actual_2024[actual_2024['Product'] == product]
  plt.plot(product_actual['Date'], product_actual['Price'], label=f'Actual {product} (Jan-Sep 2024)', marker='o', color=color_dict[product])

# Plot forecast prices and confidence intervals for top 5 products
for product in top_5_changes['Product'].unique():
  product_forecast = forecast_2024[forecast_2024['Product'] == product]
  plt.plot(product_forecast['Date'], product_forecast['Forecast'], label=f'Forecast {product} (Oct-Dec 2024)', marker='x', linestyle='--', color=color_dict[product])
  plt.fill_between(product_forecast['Date'], product_forecast['Lower CI'], product_forecast['Upper CI'], color=color_dict[product], alpha=0.2)

# Add titles and labels
plt.title("Top 5 Fruit Prices Trend with Highest Change (Jan 2024 - Dec 2024)", fontsize=14)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Price", fontsize=12)
plt.xticks(rotation=45)

# Move the legend outside the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Display the plot
plt.tight_layout()
plt.show()

# %%
df_ph['Date'] = pd.to_datetime(df_ph['Year'] + '-' + df_ph['Month'] + '-01').dt.strftime('%B %Y')

df_ph
# Out:
#             Region                       Product  Year      Month   Price  \
# 0      PHILIPPINES                       AVOCADO  2018    January   63.90
# 1      PHILIPPINES       BANANA, CARDAVA, MEDIUM  2018    January   26.68
# 2      PHILIPPINES       BANANA, LAKATAN, MEDIUM  2018    January   52.06
# 3      PHILIPPINES      BANANA, LATUNDAN, MEDIUM  2018    January   36.55
# 4      PHILIPPINES          BANANA, SABA, MEDIUM  2018    January   32.33
# ...            ...                           ...   ...        ...     ...
# 51871  PHILIPPINES  MANDARIN, DALANGHITA, MEDIUM  2024  September   73.26
# 51872  PHILIPPINES              CALAMANSI, LOOSE  2024  September   80.70
# 51873  PHILIPPINES  APPLE, RED DELICIOUS, MEDIUM  2024  September  126.85
# 51874  PHILIPPINES     CANTALOUPE, MELON, MEDIUM  2024  September   59.13
# 51875  PHILIPPINES    WATERMELON, PAKWAN, MEDIUM  2024  September   53.46
#
#       Region Abbreviation            Date
# 0                      PH    January 2018
# 1                      PH    January 2018
# 2                      PH    January 2018
# 3                      PH    January 2018
# 4                      PH    January 2018
# ...                   ...             ...
# 51871                  PH  September 2024
# 51872                  PH  September 2024
# 51873                  PH  September 2024
# 51874                  PH  September 2024
# 51875                  PH  September 2024
#
# [2916 rows x 7 columns]

# %%
from plotly.subplots import make_subplots
import plotly.graph_objs as go

# Create a figure with subplots
fig = make_subplots(rows=1, cols=1)

# Add traces for each product
for product in df_ph['Product'].unique():
  product_data = df_ph[df_ph['Product'] == product]
  fig.add_trace(go.Scatter(
    x=product_data['Date'],
    y=product_data['Price'],
    mode='lines+markers',
    name=product
  ))

# Update layout
fig.update_layout(
  title="Interactive Price Trend of Fruits from 2018 to 2024",
  xaxis_title="Date",
  yaxis_title="Price",
  legend_title="Product",
  xaxis=dict(tickangle=45)
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="12c968e1-a2b0-424d-96db-7ef6140d07f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12c968e1-a2b0-424d-96db-7ef6140d07f8")) {                    Plotly.newPlot(                        "12c968e1-a2b0-424d-96db-7ef6140d07f8",                        [{"mode":"lines+markers","name":"AVOCADO","x":["January 2018","February 2018","March 2018","April 2018","May 2018","June 2018","July 2018","August 2018","September 2018","October 2018","November 2018","December 2018","January 2019","February 2019","March 2019","April 2019","May 2019","June 2019","July 2019","August 2019","September 2019","October 2019","November 2019","December 2019","January 2020","February 2020","March 2020","April 2020","May 2020","June 2020","July 2020","August 2020","September 2020","October 2020","November 2020","December 2020","January 2021","February 2021","March 2021","April 2021","May 2021","June 2021","July 2021","August 2021","September 2021","October 2021","November 2021","December 2021","January 2022","February 2022","March 2022","April 2022","May 2022","June 2022","July 2022","August 2022","September 2022","October 2022","November 2022","December 2022","January 2023","February 2023","March 2023","April 2023","May 2023","June 2023","July 2023","August 2023","September 2023","October 2023","November 2023","December 2023","January 2024","February 2024","March 2024","April 2024","May 2024","June 2024","July 2024","August 2024","September 2024"],"y":[63.9,64.39,64.76,65.9,61.5,57.9,56.7,59.06,60.13,61.46,64.58,64.32,65.91,66.69,65.55,66.02,68.24,67.59,64.45,62.46,66.04,69.49,71.25,71.34,73.62,76.44,74.82,77.47,81.86,78.74,72.84,71.26,75.26,78.15,79.35,80.56,87.91,89.93,87.12,85.64,80.24,77.67,74.76,70.64,74.92,78.39,81.12,85.53,91.57,93.09,93.19,92.53,94.21,93.97,87.31,84.05,88.94,92.66,98.53,101.89,112.74,111.7,108.67,113.04,106.33,99.13,94.19,89.93,95.73,103.63,113.02,118.29,118.95,117.84,114.71,116.55,117.87,115.13,107.27,102.63,114.32],"type":"scatter"},{"mode":"lines+markers","name":"BANANA, CARDAVA, MEDIUM","x":["January 2018","February 2018","March 2018","April 2018","May 2018","June 2018","July 2018","August 2018","September 2018","October 2018","November 2018","December 2018","January 2019","February 2019","March 2019","April 2019","May 2019","June 2019","July 2019","August 2019","September 2019","October 2019","November 2019","December 2019","January 2020","February 2020","March 2020","April 2020","May 2020","June 2020","July 2020","August 2020","September 2020","October 2020","November 2020","December 2020","January 2021","February 2021","March 2021","April 2021","May 2021","June 2021","July 2021","August 2021","September 2021","October 2021","November 2021","December 2021","January 2022","February 2022","March 2022","April 2022","May 2022","June 2022","July 2022","August 2022","September 2022","October 2022","November 2022","December 2022","January 2023","February 2023","March 2023","April 2023","May 2023","June 2023","July 2023","August 2023","September 2023","October 2023","November 2023","December 2023","January 2024","February 2024","March 2024","April 2024","May 2024","June 2024","July 2024","August 2024","September 2024"],"y":[26.68,26.33,23.73,25.51,23.77,21.4,23.18,25.15,23.57,23.62,23.89,23.29,23.57,23.57,26.11,27.72,27.91,29.84,28.03,28.03,27.81,28.08,27.92,30.06,31.37,29.15,28.25,32.63,32.97,34.15,34.94,35.54,35.26,34.64,33.16,28.54,27.75,27.12,26.26,26.67,26.24,25.51,26.17,26.53,24.32,25.13,23.58,24.14,24.44,25.6,25.86,25.25,28.45,23.65,22.72,22.31,24.32,23.42,23.77,22.68,22.25,21.54,20.88,23.99,25.26,26.4,26.31,26.68,26.61,31.74,30.31,31.42,31.25,28.41,28.33,28.89,29.67,30.78,31.3,30.8,29.58],"type":"scatter"},{"mode":"lines+markers","name":"BANANA, LAKATA ...

# %%
# Read the Excel file named 'inflationrate.xlsx' and store it in a DataFrame
df_inflation = pd.read_excel("inflationrate.xlsx")

# Display the first few rows of the DataFrame to verify the content
df_inflation.head()
# Out:
#         Date  InflationRate  FoodInflation
# 0 2018-01-01            3.4            4.4
# 1 2018-02-01            3.8            4.8
# 2 2018-03-01            4.3            5.9
# 3 2018-04-01            4.5            5.9
# 4 2018-05-01            4.6            5.7

# %%
df_inflation['Date'] = df_inflation['Date'].dt.strftime('%B %Y')
df_inflation.head()
# Out:
#             Date  InflationRate  FoodInflation
# 0   January 2018            3.4            4.4
# 1  February 2018            3.8            4.8
# 2     March 2018            4.3            5.9
# 3     April 2018            4.5            5.9
# 4       May 2018            4.6            5.7

# %%
# Merge df_ph with df_inflation based on the 'Date' column
df_ph_merged = pd.merge(df_ph, df_inflation, on='Date', how='left')

# Display the merged DataFrame
df_ph_merged.head()
# Out:
#         Region                   Product  Year    Month  Price  \
# 0  PHILIPPINES                   AVOCADO  2018  January  63.90
# 1  PHILIPPINES   BANANA, CARDAVA, MEDIUM  2018  January  26.68
# 2  PHILIPPINES   BANANA, LAKATAN, MEDIUM  2018  January  52.06
# 3  PHILIPPINES  BANANA, LATUNDAN, MEDIUM  2018  January  36.55
# 4  PHILIPPINES      BANANA, SABA, MEDIUM  2018  January  32.33
#
#   Region Abbreviation          Date  InflationRate  FoodInflation
# 0                  PH  January 2018            3.4            4.4
# 1                  PH  January 2018            3.4            4.4
# 2                  PH  January 2018            3.4            4.4
# 3                  PH  January 2018            3.4            4.4
# 4                  PH  January 2018            3.4            4.4

# %%
# Merge df_ph with df_inflation based on the 'Date' column
df_ph_merged = pd.merge(df_ph, df_inflation, on='Date', how='left')

# Calculate the correlation matrix for InflationRate
correlation_inflation = df_ph_merged[['Price', 'InflationRate']].corr()

# Calculate the correlation matrix for FoodInflation
correlation_food_inflation = df_ph_merged[['Price', 'FoodInflation']].corr()

# Plot the correlation matrix for InflationRate
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_inflation, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation between Prices and Inflation Rate')
plt.show()

# Plot the correlation matrix for FoodInflation
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_food_inflation, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation between Prices and Food Inflation')
plt.show()

# Calculate the correlation matrix for Price, InflationRate, and FoodInflation
correlation_matrix = df_ph_merged[['Price', 'InflationRate', 'FoodInflation']].corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix: Price, Inflation Rate, and Food Inflation')
plt.show()

# %%
# Pair plot scatterplot matrix for Price, InflationRate, and FoodInflation
sns.pairplot(df_ph_merged[['Price', 'InflationRate', 'FoodInflation']])
plt.suptitle('Pair Plot Scatterplot Matrix: Price, Inflation Rate, and Food Inflation', y=1.02)
plt.show()

# %%
from plotly.subplots import make_subplots

import plotly.graph_objs as go

# Create a figure with subplots
fig = make_subplots(rows=1, cols=1)

# Add trace for Inflation Rate
fig.add_trace(go.Scatter(
  x=df_inflation['Date'],
  y=df_inflation['InflationRate'],
  mode='lines+markers',
  name='Inflation Rate'
))

# Add trace for Food Inflation
fig.add_trace(go.Scatter(
  x=df_inflation['Date'],
  y=df_inflation['FoodInflation'],
  mode='lines+markers',
  name='Food Inflation'
))

# Update layout
fig.update_layout(
  title="Inflation Rate and Food Inflation Trend",
  xaxis_title="Date",
  yaxis_title="Rate",
  legend_title="Type",
  xaxis=dict(tickangle=45)
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="dfd169db-a481-4df3-9487-fe97d15934b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dfd169db-a481-4df3-9487-fe97d15934b4")) {                    Plotly.newPlot(                        "dfd169db-a481-4df3-9487-fe97d15934b4",                        [{"mode":"lines+markers","name":"Inflation Rate","x":["January 2018","February 2018","March 2018","April 2018","May 2018","June 2018","July 2018","August 2018","September 2018","October 2018","November 2018","December 2018","January 2019","February 2019","March 2019","April 2019","May 2019","June 2019","July 2019","August 2019","September 2019","October 2019","November 2019","December 2019","January 2020","February 2020","March 2020","April 2020","May 2020","June 2020","July 2020","August 2020","September 2020","October 2020","November 2020","December 2020","January 2021","February 2021","March 2021","April 2021","May 2021","June 2021","July 2021","August 2021","September 2021","October 2021","November 2021","December 2021","January 2022","February 2022","March 2022","April 2022","May 2022","June 2022","July 2022","August 2022","September 2022","October 2022","November 2022","December 2022","January 2023","February 2023","March 2023","April 2023","May 2023","June 2023","July 2023","August 2023","September 2023","October 2023","November 2023","December 2023","January 2024","February 2024","March 2024","April 2024","May 2024","June 2024","July 2024","August 2024","September 2024"],"y":[3.4,3.8,4.3,4.5,4.6,5.2,5.7,6.4,6.7,6.7,6.0,5.1,4.4,3.8,3.3,3.0,3.2,2.7,2.4,1.7,0.9,0.8,1.3,2.5,2.9,2.6,2.2,1.8,1.6,2.3,2.4,2.2,2.2,2.3,3.0,3.3,3.7,4.2,4.1,4.1,4.1,3.7,3.7,4.4,4.2,4.0,3.7,3.1,3.0,3.0,4.0,1.9,5.4,6.1,6.4,6.3,6.9,7.7,8.0,8.1,8.7,8.6,7.6,6.6,6.1,5.4,4.7,5.3,6.1,4.9,4.1,3.9,2.8,3.4,3.7,3.8,3.9,3.7,4.4,3.3,1.9],"type":"scatter"},{"mode":"lines+markers","name":"Food Inflation","x":["January 2018","February 2018","March 2018","April 2018","May 2018","June 2018","July 2018","August 2018","September 2018","October 2018","November 2018","December 2018","January 2019","February 2019","March 2019","April 2019","May 2019","June 2019","July 2019","August 2019","September 2019","October 2019","November 2019","December 2019","January 2020","February 2020","March 2020","April 2020","May 2020","June 2020","July 2020","August 2020","September 2020","October 2020","November 2020","December 2020","January 2021","February 2021","March 2021","April 2021","May 2021","June 2021","July 2021","August 2021","September 2021","October 2021","November 2021","December 2021","January 2022","February 2022","March 2022","April 2022","May 2022","June 2022","July 2022","August 2022","September 2022","October 2022","November 2022","December 2022","January 2023","February 2023","March 2023","April 2023","May 2023","June 2023","July 2023","August 2023","September 2023","October 2023","November 2023","December 2023","January 2024","February 2024","March 2024","April 2024","May 2024","June 2024","July 2024","August 2024","September 2024"],"y":[4.4,4.8,5.9,5.9,5.7,6.1,7.1,8.5,9.7,9.4,8.0,6.7,5.6,4.7,3.4,3.0,3.4,2.7,1.9,0.6,-0.9,-0.9,0.0,1.7,2.2,2.1,2.6,3.4,2.9,2.7,2.4,1.8,1.5,2.1,4.3,4.8,5.9,6.2,5.3,3.8,3.5,3.6,3.9,5.6,5.0,3.7,2.2,1.6,1.7,1.2,2.6,3.8,4.9,6.0,6.9,6.3,7.4,9.4,10.0,10.2,10.7,10.8,9.3,7.9,7.4,6.7,6.3,8.1,9.7,7.0,5.7,5.4,3.5,4.6,5.6,6.0,5.8,6.1,6.4,3.9,1.4],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778 ...
